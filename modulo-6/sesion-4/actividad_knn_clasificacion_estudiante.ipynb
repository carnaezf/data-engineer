# %% [markdown]
# # 🌸 Clasificación de flores con K-Nearest Neighbors (K-NN)
# Actividad Formativa - Módulo 6 - Sesión 4
#
# En esta actividad entrenaremos un modelo de clasificación utilizando el algoritmo K-NN y evaluaremos su desempeño con métricas como precisión, sensibilidad, especificidad y curva ROC-AUC.
#
# ### 🔍 Objetivo
# - Entrenar un modelo K-NN con el dataset Iris
# - Evaluar con precisión, matriz de confusión, curva ROC-AUC
# - Interpretar resultados y reflexionar
#
# ---

# %%
# Paso 1: Importar librerías necesarias
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, label_binarize
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# Paso 2: Cargar el dataset Iris
iris = load_iris()


# Ingresa tu codigo aca:




# ---------------------


target_names = iris.target_names
print("Clases:", target_names)
# Out:
# Clases: ['setosa' 'versicolor' 'virginica']

# %%
# Validación adicional para asegurar que 'target_names' esté definido
try:
    target_names
except NameError:
    target_names = ['setosa', 'versicolor', 'virginica']
    print("'target_names' no estaba definido, se ha cargado valor por defecto.")

# %%
# Paso 3: Dividir en entrenamiento y prueba, y escalar los datos
# Ingresa tu codigo aca:




# ---------------------

# %%
# Paso 4: Entrenar el modelo K-NN
# Ingresa tu codigo aca:




# ---------------------

# %%
# Paso 5: Evaluación del modelo
print("Precisión:", accuracy_score(y_test, y_pred))
print("\nMatriz de Confusión:")
print(confusion_matrix(y_test, y_pred))
print("\nReporte de Clasificación:")
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Precisión: 1.0
#
# Matriz de Confusión:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# # Tu Mariz de onfusion debe verse asi:
# ![matriz-confusion.png](data:image/png;base64,...)
#
#
# # Y la Curva ROC - Clasificación Binaria:
#
# ![image.png](data:image/png;base64,...)

# %%
# Paso 6: Visualizar matriz de confusión
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.ylabel('Etiqueta Real')
plt.xlabel('Etiqueta Predicha')
plt.title('Matriz de Confusión')
plt.show()

# %%
# Paso 7: Evaluación ROC-AUC (conversión a problema binario)
# Se evalúa la clase 0 vs. las demás
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])[:, 0]
y_score = knn.predict_proba(X_test)[:, 0]
fpr, tpr, _ = roc_curve(y_test_bin, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f'Curva ROC (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC - Clasificación Binaria')
plt.legend(loc='lower right')
plt.grid()
plt.show()

# %% [markdown]
# ### ✏️ Preguntas de Reflexión
# 1. ¿Qué te indica la matriz de confusión sobre los aciertos y errores del modelo?
# 2. ¿Qué métrica te pareció más importante en este caso y por qué?
# 3. ¿Qué tan útil te resultó la curva ROC-AUC al comparar el modelo?
# 4. ¿En qué contexto usarías un modelo con alta sensibilidad y en cuál uno con alta especificidad?
# 5. ¿Cómo cambiaría el desempeño del modelo si cambiamos el valor de K?
